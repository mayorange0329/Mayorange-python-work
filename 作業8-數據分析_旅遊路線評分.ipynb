# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %% [markdown]
# ### 叫入資料
#
# Reviews on destinations in 10 categories mentioned across East Asia. Each traveler rating is mapped as Excellent(4), Very Good(3), Average(2), Poor(1), and Terrible(0)

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00484/tripadvisor_review.csv')
df.head()
# Out:
#   User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0  User 1        0.93         1.8        2.29        0.62        0.80
# 1  User 2        1.02         2.2        2.66        0.64        1.42
# 2  User 3        1.22         0.8        0.54        0.53        0.24
# 3  User 4        0.45         1.8        0.29        0.57        0.46
# 4  User 5        0.51         1.2        1.18        0.57        1.54
#
#    Category 6  Category 7  Category 8  Category 9  Category 10
# 0        2.42        3.19        2.79        1.82         2.42
# 1        3.18        3.21        2.63        1.86         2.32
# 2        1.54        3.18        2.80        1.31         2.50
# 3        1.52        3.18        2.96        1.57         2.86
# 4        2.02        3.18        2.78        1.18         2.54

# %% [markdown]
# ### 1-數量

# %%
len(df)
# Out:
# 980

# %% [markdown]
# ### 2-照Category5給分排序

# %%
df_sorted=df.sort_values(by=["Category 5"],ascending=False)
df_sorted
# Out:
#       User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 479  User 480        0.77        1.16        1.36        0.42        3.30
# 867  User 868        0.93        0.64        0.22        0.43        3.26
# 507  User 508        0.70        1.00        1.78        0.64        2.98
# 508  User 509        0.86        0.76        1.06        0.51        2.62
# 487  User 488        0.70        1.00        0.18        0.57        2.58
# 52    User 53        0.80        1.88        0.66        0.47        2.54
# 234  User 235        0.61        0.84        0.15        0.38        2.38
# 538  User 539        0.61        1.84        0.61        0.47        2.18
# 99   User 100        0.67        1.60        0.21        0.47        2.16
# 671  User 672        0.77        1.60        2.46        0.59        2.16
# 626  User 627        0.80        1.92        1.60        0.50        2.08
# 32    User 33        0.64        2.00        1.60        0.41        2.08
# ...

# %% [markdown]
# ### 3-算Category 5的給分平均與標準差

# %%
df['Category 5'].mean()
# Out:
# 0.9397346938775518

# %%
df['Category 5'].std()
# Out:
# 0.4374299664015203

# %% [markdown]
# ### 4-將Category 10刪除

# %%
dfs=df.drop("Category 10",axis = 1) 
dfs
# Out:
#       User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0      User 1        0.93        1.80        2.29        0.62        0.80
# 1      User 2        1.02        2.20        2.66        0.64        1.42
# 2      User 3        1.22        0.80        0.54        0.53        0.24
# 3      User 4        0.45        1.80        0.29        0.57        0.46
# 4      User 5        0.51        1.20        1.18        0.57        1.54
# 5      User 6        0.99        1.28        0.72        0.27        0.74
# 6      User 7        0.90        1.36        0.26        0.32        0.86
# 7      User 8        0.74        1.40        0.22        0.41        0.82
# 8      User 9        1.12        1.76        1.04        0.64        0.82
# 9     User 10        0.70        1.36        0.22        0.26        1.50
# 10    User 11        1.47        1.00        0.70        0.75        1.66
# 11    User 12        0.96        2.96        0.29        0.38        0.88
# ...
